# %%
import pandas as pd
import glob
import os

# %%
base_path = '../../src/fetch_tissue_data/.oncoexporter_cache/'
glob_pattern = os.path.join(base_path, '**', '*')
files = glob.glob(glob_pattern, recursive=True)

# %%
keyword = 'Colon'
dataframes = {}

for file in files:
    if keyword in file:
        df_name = file.split('/')[-1].replace('.pkl', '').replace('_df', '').replace(f'{keyword}_', '')
        dataframes[df_name] = pd.read_pickle(file)

# %%
required_keys = ['mutation', 'diagnosis', 'individual', 'rsub', 'specimen', 'treatment']
missing_keys = [key for key in required_keys if key not in dataframes]

if missing_keys:
    print(f"Missing dataframes for keys: {missing_keys}")
else:
    print("All required keys are present.")
# Out:
# All required keys are present.

# %% [markdown]
# ## Step 1: Merge diagnosis and individual dataframes

# %%
merged_df = pd.merge(dataframes['diagnosis'], dataframes['individual'], on='subject_id', how='left', suffixes=('_diag', '_ind'))

# %% [markdown]
# ## Step 2: Merge with research subject dataframe

# %%
merged_df = pd.merge(merged_df, dataframes['rsub'], on='researchsubject_id', how='left', suffixes=('', '_rsub'))

# %% [markdown]
# ## Step 3: Merge with specimen dataframe

# %%
merged_df = pd.merge(merged_df, dataframes['specimen'], on='researchsubject_id', how='left', suffixes=('', '_spec'))

# %% [markdown]
# ## Step 4: Merge with treatment dataframe

# %%
merged_df = pd.merge(merged_df, dataframes['treatment'], on='researchsubject_id', how='left', suffixes=('', '_treat'))

# %% [markdown]
# ## Step 5: Merge with mutation dataframe

# %%
merged_df = pd.merge(merged_df, dataframes['mutation'], left_on='subject_id', right_on='cda_subject_id', how='left', suffixes=('', '_mut'))

# %% [markdown]
# ## Get unique rows based on certain columns

# %%
unique_rows_df = merged_df.drop_duplicates(subset=['primary_diagnosis', 'primary_diagnosis_condition', 'primary_diagnosis_site']).reset_index(drop=True)[['primary_diagnosis', 'primary_diagnosis_condition', 'primary_diagnosis_site']]

# %%
unique_rows_df
# Out:
#                                     primary_diagnosis  \
# 0                                 Adenocarcinoma, NOS
# 1                             Mucinous adenocarcinoma
# 2                               Goblet cell carcinoid
# 3                            Medullary carcinoma, NOS
# 4                                 Adenocarcinoma, NOS
# 5                                  Mucinous carcinoma
# 6                          Signet ring cell carcinoma
# 7                       Neuroendocrine carcinoma, NOS
# 8                     Adenocarcinoma, metastatic, NOS
# 9                       Papillary adenocarcinoma, NOS
# 10                                Adenocarcinoma, NOS
# 11                              Not specified in data
# 12                            Mucinous adenocarcinoma
# 13                         Tubulovillous adenoma, NOS
# 14                               Tubular adenoma, NOS
# 15                               Carcinoid tumor, NOS
# 16                                         Tumor, NOS
# 17                                     Adenocarcinoma
# 18                 Adenocarcinoma with mixed subtypes
# 19                                   Serrated adenoma
# 20                                           Neoplasm
# 21                                       Not Reported
# 22                                     Carcinoma, NOS
# 23                          Small cell carcinoma, NOS
# 24                            Mucinous adenocarcinoma
# 25  Well to moderately differentiated colonic aden...
# 26                        Transitional cell carcinoma
# 27                        Adenocarcinoma in situ, NOS
# 28                    Adenocarcinoma, intestinal type
# 29     Malignant lymphoma, large B-cell, diffuse, NOS
# 30  Adenocarcinoma with neuroendocrine differentia...
# 31                                       Not Reported
# 32                                Adenocarcinoma, NOS
# 33                       Dedifferentiated liposarcoma
# 34                            Adenosquamous carcinoma
# 35                            Adenosquamous carcinoma
#
#               primary_diagnosis_condition primary_diagnosis_site
# 0            Adenomas and Adenocarcinomas                  Colon
# 1   Cystic, Mucinous and Serous Neoplasms                  Colon
# 2            Adenomas and Adenocarcinomas                  Colon
# 3            Ductal and Lobular Neoplasms                  Colon
# 4                    Colon Adenocarcinoma                  Colon
# 5   Cystic, Mucinous and Serous Neoplasms                  Colon
# 6   Cystic, Mucinous and Serous Neoplasms                  Colon
# 7            Adenomas and Adenocarcinomas                  Colon
# 8            Adenomas and Adenocarcinomas                  Colon
# 9            Adenomas and Adenocarcinomas                  Colon
# 10                         Neoplasms, NOS                  Colon
# 11                    Adenocarcinoma, NOS             Colon, NOS
# 12                   Colon Adenocarcinoma                  Colon
# 13           Adenomas and Adenocarcinomas                  Colon
# 14           Adenomas and Adenocarcinomas                  Colon
# 15           Adenomas and Adenocarcinomas                  Colon
# 16                         Neoplasms, NOS                  Colon
# 17                    Epithelial Neoplasm                  Colon
# 18           Adenomas and Adenocarcinomas                  Colon
# 19           Adenomas and Adenocarcinomas                  Colon
# 20                               Neoplasm                  Colon
# 21                         Neoplasms, NOS                  Colon
# 22              Epithelial Neoplasms, NOS                  Colon
# 23                         Neoplasms, NOS                  Colon
# 24                         Neoplasms, NOS                  Colon
# 25                    Adenocarcinoma, NOS             Colon, NOS
# 26           Adenomas and Adenocarcinomas                  Colon
# 27           Adenomas and Adenocarcinomas                  Colon
# 28           Adenomas and Adenocarcinomas                  Colon
# 29                Mature B-Cell Lymphomas                  Colon
# 30           Complex Epithelial Neoplasms                  Colon
# 31           Adenomas and Adenocarcinomas                  Colon
# 32  Cystic, Mucinous and Serous Neoplasms                  Colon
# 33                   Lipomatous Neoplasms                  Colon
# 34           Complex Epithelial Neoplasms                  Colon
# 35                   Colon Adenocarcinoma                  Colon

# %%
unique_rows_df.to_csv(f'../CombinationsForTissues/results/{keyword}_unique_combination.csv')
