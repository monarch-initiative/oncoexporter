# %%
import pandas as pd
import glob
import os

# %%
base_path = '../../src/fetch_tissue_data/.oncoexporter_cache/'
glob_pattern = os.path.join(base_path, '**', '*')
files = glob.glob(glob_pattern, recursive=True)

# %%
keyword = 'Bone'
dataframes = {}

for file in files:
    if keyword in file:
        df_name = file.split('/')[-1].replace('.pkl', '').replace('_df', '').replace(f'{keyword}_', '')
        dataframes[df_name] = pd.read_pickle(file)

# %%
required_keys = ['mutation', 'diagnosis', 'individual', 'rsub', 'specimen', 'treatment']
missing_keys = [key for key in required_keys if key not in dataframes]

if missing_keys:
    print(f"Missing dataframes for keys: {missing_keys}")
else:
    print("All required keys are present.")
# Out:
# All required keys are present.

# %% [markdown]
# ## Step 1: Merge diagnosis and individual dataframes

# %%
merged_df = pd.merge(dataframes['diagnosis'], dataframes['individual'], on='subject_id', how='left', suffixes=('_diag', '_ind'))

# %% [markdown]
# ## Step 2: Merge with research subject dataframe

# %%
merged_df = pd.merge(merged_df, dataframes['rsub'], on='researchsubject_id', how='left', suffixes=('', '_rsub'))

# %% [markdown]
# ## Step 3: Merge with specimen dataframe

# %%
merged_df = pd.merge(merged_df, dataframes['specimen'], on='researchsubject_id', how='left', suffixes=('', '_spec'))

# %% [markdown]
# ## Step 4: Merge with treatment dataframe

# %%
merged_df = pd.merge(merged_df, dataframes['treatment'], on='researchsubject_id', how='left', suffixes=('', '_treat'))

# %% [markdown]
# ## Step 5: Merge with mutation dataframe

# %%
merged_df = pd.merge(merged_df, dataframes['mutation'], left_on='subject_id', right_on='cda_subject_id', how='left', suffixes=('', '_mut'))

# %% [markdown]
# ## Get unique rows based on certain columns

# %%
unique_rows_df = merged_df.drop_duplicates(subset=['primary_diagnosis', 'primary_diagnosis_condition', 'primary_diagnosis_site']).reset_index(drop=True)[['primary_diagnosis', 'primary_diagnosis_condition', 'primary_diagnosis_site']]

# %%
unique_rows_df
# Out:
#                                  primary_diagnosis  \
# 0                              Chondrosarcoma, NOS
# 1                                Osteosarcoma, NOS
# 2                                    Ewing sarcoma
# 3                                Osteosarcoma, NOS
# 4                                    Chordoma, NOS
# 5                            Not specified in data
# 6                  High grade surface osteosarcoma
# 7                         Undifferentiated sarcoma
# 8                                 Rhabdomyosarcoma
# 9                            Myxoid chondrosarcoma
# 10                              Neuroblastoma, NOS
# 11                     Chondroblastic osteosarcoma
# 12                   Round to spindle cell sarcoma
# 13   Intraosseous well differentiated osteosarcoma
# 14                           Not specified in data
# 15                Clear cell odontogenic carcinoma
# 16                      Mesenchymal chondrosarcoma
# 17                 Dedifferentiated chondrosarcoma
# 18                           Not specified in data
# 19                           Not specified in data
# 20                       Fibroblastic osteosarcoma
# 21                    Odontogenic tumor, malignant
# 22                             Neoplasm, malignant
# 23                                      Myofibroma
# 24                                    Sarcoma, NOS
# 25                           Not specified in data
# 26                              Neuroblastoma, NOS
# 27                    Squamous cell carcinoma, NOS
# 28           Osteosarcoma in Paget disease of bone
# 29                             Leiomyosarcoma, NOS
# 30                           Not specified in data
# 31  Malignant lymphoma, large B-cell, diffuse, NOS
# 32                                    Not Reported
# 33                           Not specified in data
# 34                         Small cell osteosarcoma
# 35                           Not specified in data
# 36                           Not specified in data
# 37                                      Tumor, NOS
# 38                           Not specified in data
# 39                             Pleomorphic Sarcoma
# 40                            Chondroblastoma, NOS
# 41      Undifferential small round blue cell tumor
# 42                   Giant cell tumor of bone, NOS
#
#                         primary_diagnosis_condition  \
# 0               Osseous and Chondromatous Neoplasms
# 1               Osseous and Chondromatous Neoplasms
# 2                         Miscellaneous Bone Tumors
# 3               Osseous and Chondromatous Neoplasms
