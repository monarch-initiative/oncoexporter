# %%
import os
from google.protobuf.json_format import MessageToJson

# https://cda.readthedocs.io/en/latest/documentation/cdapython/code_update/#install
#from cdapython import Q
from cdapython import tables, columns, column_values, fetch_rows, summary_counts # updated CDA 
from oncoexporter.cda import CdaTableImporter, configure_cda_table_importer

'''
https://cda.readthedocs.io/en/latest/documentation/cdapython/code_update/#returning-a-matrix-of-results
old: all of the functions previously used with, or chained onto Q()...run() have been replaced with the single function fetch_rows()

fetch_rows(table=None, *, match_all=[], match_any=[], data_source=[], add_columns=[], link_to_table='', provenance=False, count_only=False, return_data_as='dataframe', output_file='', debug=False)

fetch_rows( table='subject', match_all=[ 'primary_disease_type = *duct*', 'sex = F*' ] )
fetch_rows( table='researchsubject', match_all=[ 'primary_diagnosis_site = NULL' ] )
'''
######   Input parameters  ########
table_importer: CdaTableImporter = configure_cda_table_importer(use_cache=False)

#Tsite = Q('primary_diagnosis_site = "%lung%" OR primary_diagnosis_site = "%pulmonary%"')
# b = {'x':42, 'y':None}
# function(1, **b) # equal to function(1, x=42, y=None)
Query = {'match_any': ['primary_diagnosis_site = *lung*' , 'primary_diagnosis_site = *pulmonary*'],
         'data_source': 'GDC'}
cohort_name = 'Lung'
#################################### 
 
p = table_importer.get_ga4gh_phenopackets(Query, cohort_name=cohort_name)
p[0]
result_dir = os.path.abspath(os.path.join('phenopackets', cohort_name))
#os.makedirs(result_dir, exist_ok=True) # overwrite existing directory

#print(f'Writing {len(p)} phenopackets to {result_dir}')
#for pp in p:
#    file_path = os.path.join(result_dir, f'{pp.id}.json')
#    with open(file_path, 'w') as fh:
#        json = MessageToJson(pp)
#        fh.write(json)
# Out:
# Getting subject df...
# 	calling CDA function
# obtained subject_df
#
# Getting merged diagnosis and researchsubject df...
# 	calling CDA function
# obtained diagnosis_df
# 	calling CDA function
# obtained researchsubject_df
# obtained merged diagnosis researchsubject df
#
# Getting specimen df...
# 	calling CDA function
#
# Getting treatment df...
# 	calling CDA function
#
# Getting merged subject and researchsubject df...
# 	calling CDA function
# 	calling CDA function
# obtained merged subject and researchsubject df
#
# Converting to Phenopackets...
# individual dataframe: 100%|██████████| 5415/5415 [00:00<00:00, 15806.02it/s]
# merged diagnosis and researchsubject dataframe:  42%|████▏     | 2226/5359 [00:00<00:00, 11150.12it/s]
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# merged diagnosis and researchsubject dataframe:  83%|████████▎ | 4445/5359 [00:00<00:00, 11009.89it/s]
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# ...
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# cda stage:
# stage:
# specimen/biosample dataframe: 100%|██████████| 68098/68098 [00:05<00:00, 13345.58it/s]
# subject researchsubject dataframe:   0%|          | 4/5415 [00:03<1:12:12,  1.25it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 29
#      26 cohort_name = 'Lung'
#      27 ####################################
# ---> 29 p = table_importer.get_ga4gh_phenopackets(Query, cohort_name=cohort_name)
#      30 p[0]
#      31 result_dir = os.path.abspath(os.path.join('phenopackets', cohort_name))
#
# File ~/Library/CloudStorage/OneDrive-NationalInstitutesofHealth/Phenopackets/oncoexporter/src/oncoexporter/cda/cda_table_importer.py:324, in CdaTableImporter.get_ga4gh_phenopackets(self, source, **kwargs)
#     321 #print(row["subject_id"], subj_id)
#     323 variant_interpretations = self._gdc_mutation_service.fetch_variants(subj_id) # was rsub_subj['value']
# --> 324 vital_status = self._gdc_mutation_service.fetch_vital_status(subj_id)
#     325 if len(variant_interpretations) == 0:
#     326     #print("No variants found")
#     327     continue
#
# File ~/Library/CloudStorage/OneDrive-NationalInstitutesofHealth/Phenopackets/oncoexporter/src/oncoexporter/cda/_gdc.py:85, in GdcMutationService.fetch_vital_status(self, subject_id)
#      84 def fetch_vital_status(self, subject_id: str) -> pp.VitalStatus:
# ---> 85     survival_data = self._fetch_data_from_gdc(self._survival_url, subject_id)
#      86     vital_status_data = self._fetch_data_from_gdc(self._cases, subject_id, self._case_fields)
#      88     survival_time = None
#
# File ~/Library/CloudStorage/OneDrive-NationalInstitutesofHealth/Phenopackets/oncoexporter/src/oncoexporter/cda/_gdc.py:50, in GdcMutationService._fetch_data_from_gdc(self, url, subject_id, fields)
#      48 def _fetch_data_from_gdc(self, url: str, subject_id: str, fields: typing.List[str]=None) -> typing.Any:
#      49     params = self._prepare_query_params(subject_id, fields)
# ---> 50     response = requests.get(url, params=params, timeout=self._timeout)
#      51     if response.status_code == 200:
#      52         data = response.json()
#
# File ~/anaconda3/envs/Phenopackets/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/anaconda3/envs/Phenopackets/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/anaconda3/envs/Phenopackets/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/envs/Phenopackets/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/envs/Phenopackets/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/anaconda3/envs/Phenopackets/lib/python3.11/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/anaconda3/envs/Phenopackets/lib/python3.11/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/anaconda3/envs/Phenopackets/lib/python3.11/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~/anaconda3/envs/Phenopackets/lib/python3.11/http/client.py:1390, in HTTPConnection.getresponse(self)
#    1388 try:
#    1389     try:
# -> 1390         response.begin()
#    1391     except ConnectionError:
#    1392         self.close()
#
# File ~/anaconda3/envs/Phenopackets/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File ~/anaconda3/envs/Phenopackets/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File ~/anaconda3/envs/Phenopackets/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~/anaconda3/envs/Phenopackets/lib/python3.11/ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/envs/Phenopackets/lib/python3.11/ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
from cdapython import tables, columns, column_values,  fetch_rows, summary_counts
columns(return_data_as='', output_file='', sort_by='', debug=False, table='Diagnosis')
# Out:
#        table               column data_type  nullable  \
# 0  diagnosis         diagnosis_id      text     False
# 1  diagnosis     age_at_diagnosis   integer      True
# 2  diagnosis                grade      text      True
# 3  diagnosis  method_of_diagnosis      text      True
# 4  diagnosis           morphology      text      True
# 5  diagnosis    primary_diagnosis      text      True
# 6  diagnosis                stage      text      True
#
#                                          description
# 0  The logical identifier of the entity in the re...
# 1  The age in days of the individual at the time ...
# 2  The degree of abnormality of cancer cells, a m...
# 3  The method used to confirm the subjects malign...
# 4  Code that represents the histology of the dise...
# 5  The diagnosis instance that qualified a subjec...
# 6  The extent of a cancer in the body. Staging is...
